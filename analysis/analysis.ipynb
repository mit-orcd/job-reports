# %%
import pandas as pd

# %%
df = pd.read_csv("../data/202512-sacct.csv")
df.head()
# Out:
#       jobid  jobidraw cluster               partition     qos      account  \
# 0  65048059  65048059   eofe7        sched_mit_darwin  normal  mit_general
# 1  65889199  65889199   eofe7  sched_engaging_default  normal  mit_general
# 2  66319279  66319279   eofe7          sched_mit_psfc  normal  mit_general
# 3  66483720  66483720   eofe7          sched_mit_psfc  normal  mit_general
# 4    424018    424018   eofe7          sched_mit_psfc  normal  mit_general
#
#       group     gid      user     uid  ... reqtres_nodes reqtres_gpu  \
# 0  gbritten  173513  gbritten  173513  ...             1           0
# 1  kexindai  195091  kexindai  195091  ...             1           0
# 2     stlam  120767     stlam  120767  ...             4           0
# 3     stlam  120767     stlam  120767  ...             4           0
# 4     stlam  120767     stlam  120767  ...             4           0
#
#   reqtres_gpu_type alloctres_cpu alloctres_mem_mb alloctres_nodes  \
# ...

# %%
df['nodelist']
# Out:
# 0         None assigned
# 1         None assigned
# 2         None assigned
# 3         None assigned
# 4         None assigned
#               ...
# 827284         node2705
# 827285         node2705
# 827286         node2705
# 827287         node1603
# 827288         node3903
# Name: nodelist, Length: 827289, dtype: object

# %%
df.columns
# Out:
# Index(['jobid', 'jobidraw', 'cluster', 'partition', 'qos', 'account', 'group',
#        'gid', 'user', 'uid', 'submit', 'eligible', 'start', 'end', 'elapsed',
#        'exitcode', 'state', 'nnodes', 'ncpus', 'reqcpus', 'reqmem', 'reqtres',
#        'alloctres', 'timelimit', 'nodelist', 'jobname', 'elapsed_seconds',
#        'state_clean', 'reqtres_cpu', 'reqtres_mem_mb', 'reqtres_nodes',
#        'reqtres_gpu', 'reqtres_gpu_type', 'alloctres_cpu', 'alloctres_mem_mb',
#        'alloctres_nodes', 'alloctres_gpu', 'alloctres_gpu_type', 'cpu_hours',
#        'wait_time'],
#       dtype='object')

# %%
df.alloctres.unique()
# Out:
# array([nan, 'billing=1,cpu=1,mem=1000M,node=1',
#        'billing=1,cpu=1,mem=500G,node=1', ...,
#        'billing=20,cpu=20,gres/gpu:h100=1,gres/gpu=1,mem=100G,node=1',
#        'billing=212,cpu=212,mem=212000M,node=11',
#        'billing=100,cpu=100,mem=100000M,node=5'],
#       shape=(2730,), dtype=object)

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df.qos.value_counts()
# Out:
# qos
# normal                                   822306
# rres_qos_fisherp_2025-11-30_tzzfk0uj       2769
# unlimited                                  1174
# rres_qos_secorey_2025-10-22_e0d267kn        633
# rres_qos_hjkulik_2025-12-05_mqwbmo56        137
# rres_qos_gelbanna_2025-11-06_jd7b0go6       128
# rres_qos_luowl7_2025-07-28_ha0hxf2v          77
# rres_qos_sherwang_2025-12-04_qoehn463        36
# rres_qos_jahn_2025-10-30_ge7subr8            10
# rres_qos_dvdai_2025-12-10_dsij221m            9
# rres_qos_cnh_2025-09-23_m8139oyi              6
# rres_qos_vinithms_2025-11-26_3vn4rzvu         2
# rres_qos_danlim_2025-10-22_7fblfb3n           2
# Name: count, dtype: int64
